# %%
# !pip install datasets
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 469.0/469.0 KB 7.1 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 132.9/132.9 KB 11.5 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 110.5/110.5 KB 5.6 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.0/1.0 MB 19.4 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 212.2/212.2 KB 2.1 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 199.8/199.8 KB 7.3 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 114.2/114.2 KB 703.3 kB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 264.6/264.6 KB 12.0 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 158.8/158.8 KB 7.5 MB/s eta 0:00:00
# ...

# %%
from datasets import load_dataset
import pandas as pd

# %%
access_token = "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"


TG_data = load_dataset("skg/toxigen-data", name="train", use_auth_token=access_token) # 250k training examples
#TG_annotations = load_dataset("skg/toxigen-data", name="annotated", use_auth_token=True) # Human study
# Out:
# ...
# Generating train split: 0 examples [00:00, ? examples/s]
# Dataset toxigen-data downloaded and prepared to /root/.cache/huggingface/datasets/skg___toxigen-data/train/1.1.0/3dd39bc1508e10d3eebcca2f60948e1529149c78a24594fd929aaa1f1bda74d0. Subsequent calls will reuse this data.
#   0%|          | 0/1 [00:00<?, ?it/s]

# %%
TG = pd.DataFrame(TG_data["train"]) # Toxigen is stored in the train split of a huggingface dataset
TG.head()
# Out:
#                                               prompt  \
# 0  - the vast majority of african-americans are p...
# 1  - black people from the middle ages have alway...
# 2  - many african americans are so savage they lo...
# 3  - the vast majority of african-americans are p...
# 4  - whether a scientist or janitor, black people...
#
#                                           generation generation_method  group  \
# 0  if youre white, you should be proud to be whit...             ALICE  black
# 1  the best thing that could have happened to the...             ALICE  black
# 2  theres no hope for the future because theres n...             ALICE  black
# 3         if youre white, you should be proud of it.             ALICE  black
# 4  no matter how much money or power you have, if...             ALICE  black
#
#    prompt_label  roberta_prediction
# 0             1               0.001
# 1             1               0.044
# 2             1               0.014
# ...

# %%
# Example of loading only neutral examples
neutral_examples = TG[TG.prompt_label == 0.0]
neutral_examples.head()
# Out:
#                                                   prompt  \
# 57948  - african american women have a different inve...
# 57949  - african american women have a different inve...
# 57950  - african american women have a different inve...
# 57951  - african american women have a different inve...
# 57952  - african american women have a different inve...
#
#                                               generation generation_method  \
# 57948   a black transgender man, regularly talks need...             top-k
# 57949   black girls don't have a seat at the table of...             top-k
# 57950   by and large, white americans have been uniqu...             top-k
# 57951   it seems that there's still a deep discomfort...             top-k
# 57952   Black womens equality and role within society...             top-k
#
#        group  prompt_label  roberta_prediction
# 57948  black             0               0.001
# 57949  black             0               0.001
# ...

# %%
# Example of loading only toxic examples
toxic_examples = TG[TG.prompt_label == 1.0]
toxic_examples.head()
# Out:
#                                               prompt  \
# 0  - the vast majority of african-americans are p...
# 1  - black people from the middle ages have alway...
# 2  - many african americans are so savage they lo...
# 3  - the vast majority of african-americans are p...
# 4  - whether a scientist or janitor, black people...
#
#                                           generation generation_method  group  \
# 0  if youre white, you should be proud to be whit...             ALICE  black
# 1  the best thing that could have happened to the...             ALICE  black
# 2  theres no hope for the future because theres n...             ALICE  black
# 3         if youre white, you should be proud of it.             ALICE  black
# 4  no matter how much money or power you have, if...             ALICE  black
#
#    prompt_label  roberta_prediction
# 0             1               0.001
# 1             1               0.044
# 2             1               0.014
# ...

# %%
#Get only the hate data
identity_hate_data = TG[TG.prompt_label == 1.0]
identity_hate_data.shape
# Out:
# (125672, 6)

# %%
identity_hate_data = identity_hate_data.sample(frac=.1).reset_index(drop=True)
identity_hate_data.shape
# Out:
# (12567, 6)

# %%
identity_hate_data.head()
# Out:
#                                               prompt  \
# 0  - the way i see it, if i have to work hard to ...
# 1  - its so funny to park in the parking spaces r...
# 2  - one group who really is all the same is the ...
# 3  - no one would date someone who uses a wheelch...
# 4  - all greedy people have great big jewish nose...
#
#                                           generation generation_method  \
# 0   Trump is not about racism, but about illegal ...             top-k
# 1   people with disabilities deserve pity, not re...             top-k
# 2  I have to agree with you on that. The Jews wer...             top-k
# 3   Disabled people are more homely\n- one of you...             top-k
# 4  no matter how filthy rich you are and no matte...             top-k
#
#           group  prompt_label  roberta_prediction
# 0       mexican             1               0.965
# 1  physical_dis             1               0.005
# 2        jewish             1               0.001
# ...

# %%
identity_hate_data = identity_hate_data[['generation']]
identity_hate_data.head()
# Out:
#                                           generation
# 0   Trump is not about racism, but about illegal ...
# 1   people with disabilities deserve pity, not re...
# 2  I have to agree with you on that. The Jews wer...
# 3   Disabled people are more homely\n- one of you...
# 4  no matter how filthy rich you are and no matte...

# %%
identity_hate_data = identity_hate_data.rename(columns={"generation": "comment_text"})
identity_hate_data['obscene'] = 0
identity_hate_data['threat'] = 0
identity_hate_data['insult'] = 0
identity_hate_data['toxic'] = 1
identity_hate_data['severe_toxic'] = 1
identity_hate_data['identity_hate'] = 1
identity_hate_data.head()
# Out:
#                                         comment_text  obscene  threat  insult  \
# 0   Trump is not about racism, but about illegal ...        0       0       0
# 1   people with disabilities deserve pity, not re...        0       0       0
# 2  I have to agree with you on that. The Jews wer...        0       0       0
# 3   Disabled people are more homely\n- one of you...        0       0       0
# 4  no matter how filthy rich you are and no matte...        0       0       0
#
#    toxic  severe_toxic  identity_hate
# 0      1             1              1
# 1      1             1              1
# 2      1             1              1
# 3      1             1              1
# 4      1             1              1

# %%
from google.colab import drive
drive.mount('/content/drive')
identity_hate_data.to_csv("/content/drive/My Drive/Colab Notebooks/w266project/toxigen_data.csv")
# Out:
# Mounted at /content/drive
